# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishGutte/remote_repo_python/blob/main/text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.tokenize import word_tokenize

sent5 = "We're here to help! mail us at nks@gmail.com"
tokens = word_tokenize(sent5)
print(tokens)
# Out:
# ['We', "'re", 'here', 'to', 'help', '!', 'mail', 'us', 'at', 'nks', '@', 'gmail.com']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp('My name is Ashish gutte')

# %%
for token in doc1:
    print(token)
# Out:
# My
# name
# is
# Ashish
# gutte

# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %%
# !pip install wget

# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# --2024-10-25 08:56:08--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 3.5.12.76, 52.217.69.246, 16.15.184.226, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|3.5.12.76|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-10-25 08:56:09 ERROR 404: Not Found.

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']

# %%
model = KeyedVectors.load_word2vec_format(vec_king,binary=False,limit=500000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-69fa9001498d> in <cell line: 1>()
# ----> 1 model = KeyedVectors.load_word2vec_format(vec_king,binary=False,limit=500000)
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1717
#    1718         """
# -> 1719         return _load_word2vec_format(
#    1720             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1721             limit=limit, datatype=datatype, no_header=no_header,
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2046
# ...

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
vec_king.most_similar('man')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-aeb31dd12dbd> in <cell line: 1>()
# ----> 1 vec_king.most_similar('man')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'most_similar'

# %%
vec_king.most_similar('cricket')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-c57b518dd315> in <cell line: 1>()
# ----> 1 vec_king.most_similar('cricket')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'most_similar'

# %%
vec_king = model['king']  # This is a numpy array, not a KeyedVectors object
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-d899ae51659a> in <cell line: 1>()
# ----> 1 vec_king = model['king']  # This is a numpy array, not a KeyedVectors object
#
# NameError: name 'model' is not defined

# %%
vec_king.similarity('man','woman')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-faa5c3576681> in <cell line: 1>()
# ----> 1 vec_king.similarity('man','woman')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'similarity'
